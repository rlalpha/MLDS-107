# %%
from keras.datasets import cifar10
from keras.utils import np_utils
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Using TensorFlow backend.

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %%
import hw1_2 as cnn

# %%
y_train = np_utils.to_categorical(y_train)
y_test = np_utils.to_categorical(y_test)

# %%
cnn.train.counter = 0
cnn.train(x_train, y_train, x_test, y_test, 100, 'CIFAR10')
# Out:
# model_1 build
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 28)        784
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 28)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 30, 30, 28)        7084
# _________________________________________________________________
# activation_2 (Activation)    (None, 30, 30, 28)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 28)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 28)        7084
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 28)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 28)        7084
# _________________________________________________________________
# activation_4 (Activation)    (None, 11, 11, 28)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 28)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 28)          7084
# _________________________________________________________________
# activation_5 (Activation)    (None, 4, 4, 28)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 448)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              459776
# _________________________________________________________________
# activation_6 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 499,146
# Trainable params: 499,146
# Non-trainable params: 0
# _________________________________________________________________
# None
# model_2 build
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 32, 32, 28)        2128
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 32, 28)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 16, 16, 28)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 28)        19628
# _________________________________________________________________
# activation_8 (Activation)    (None, 12, 12, 28)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 28)          19628
# _________________________________________________________________
# activation_9 (Activation)    (None, 8, 8, 28)          0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 28)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 448)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              459776
# _________________________________________________________________
# activation_10 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 511,410
# Trainable params: 511,410
# Non-trainable params: 0
# _________________________________________________________________
# None
# model_3 build
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_3 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               786688
# _________________________________________________________________
# activation_11 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_12 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# activation_13 (Activation)   (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 920,842
# Trainable params: 920,842
# Non-trainable params: 0
# _________________________________________________________________
# None
# model_4 build
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_4 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               393344
# _________________________________________________________________
# activation_14 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_15 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_16 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_17 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_18 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_19 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_20 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_21 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_22 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_23 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_24 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_25 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 576,266
# Trainable params: 576,266
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 168s 3ms/step - loss: 2.8258 - acc: 0.2057 - val_loss: 1.7850 - val_acc: 0.3503
# Epoch 2/100
# 50000/50000 [==============================] - 142s 3ms/step - loss: 1.6780 - acc: 0.3893 - val_loss: 1.5623 - val_acc: 0.4254
# Epoch 3/100
# 50000/50000 [==============================] - 123s 2ms/step - loss: 1.4795 - acc: 0.4627 - val_loss: 1.4293 - val_acc: 0.4815
# Epoch 4/100
# 50000/50000 [==============================] - 2771s 55ms/step - loss: 1.3597 - acc: 0.5121 - val_loss: 1.3145 - val_acc: 0.5259
# Epoch 5/100
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.2304 - acc: 0.5623 - val_loss: 1.2670 - val_acc: 0.5398
# Epoch 6/100
# 50000/50000 [==============================] - 180s 4ms/step - loss: 1.1589 - acc: 0.5916 - val_loss: 1.2301 - val_acc: 0.5575
# Epoch 7/100
# 50000/50000 [==============================] - 176s 4ms/step - loss: 1.0701 - acc: 0.6228 - val_loss: 1.1999 - val_acc: 0.5727
# Epoch 8/100
# 50000/50000 [==============================] - 562s 11ms/step - loss: 0.9878 - acc: 0.6522 - val_loss: 1.1498 - val_acc: 0.5931
# Epoch 9/100
# 50000/50000 [==============================] - 1073s 21ms/step - loss: 0.9182 - acc: 0.6767 - val_loss: 1.1280 - val_acc: 0.5997
# Epoch 10/100
# 50000/50000 [==============================] - 1020s 20ms/step - loss: 0.8398 - acc: 0.7080 - val_loss: 1.1436 - val_acc: 0.6057
# Epoch 11/100
# 50000/50000 [==============================] - 1040s 21ms/step - loss: 0.7864 - acc: 0.7252 - val_loss: 1.1323 - val_acc: 0.6131
# Epoch 12/100
# 50000/50000 [==============================] - 1032s 21ms/step - loss: 0.7349 - acc: 0.7445 - val_loss: 1.1538 - val_acc: 0.6159
# Epoch 13/100
# 50000/50000 [==============================] - 1039s 21ms/step - loss: 0.6632 - acc: 0.7715 - val_loss: 1.2138 - val_acc: 0.6006
# Epoch 14/100
# 50000/50000 [==============================] - 1058s 21ms/step - loss: 0.6033 - acc: 0.7920 - val_loss: 1.2238 - val_acc: 0.6120
# Epoch 15/100
# 50000/50000 [==============================] - 1063s 21ms/step - loss: 0.5342 - acc: 0.8159 - val_loss: 1.2701 - val_acc: 0.6195
# Epoch 16/100
# 50000/50000 [==============================] - 1068s 21ms/step - loss: 0.4760 - acc: 0.8386 - val_loss: 1.3255 - val_acc: 0.6149
# Epoch 17/100
# 50000/50000 [==============================] - 1054s 21ms/step - loss: 0.4012 - acc: 0.8656 - val_loss: 1.3824 - val_acc: 0.6224
# Epoch 18/100
# 50000/50000 [==============================] - 3031s 61ms/step - loss: 0.3785 - acc: 0.8710 - val_loss: 1.4186 - val_acc: 0.6158
# Epoch 19/100
# 50000/50000 [==============================] - 2377s 48ms/step - loss: 0.3254 - acc: 0.8905 - val_loss: 1.5326 - val_acc: 0.6192
# Epoch 20/100
# 50000/50000 [==============================] - 768s 15ms/step - loss: 0.2724 - acc: 0.9101 - val_loss: 1.6153 - val_acc: 0.6161
# Epoch 21/100
# 50000/50000 [==============================] - 1130s 23ms/step - loss: 0.2309 - acc: 0.9243 - val_loss: 1.6987 - val_acc: 0.6186
# Epoch 22/100
# 50000/50000 [==============================] - 373s 7ms/step - loss: 0.1917 - acc: 0.9376 - val_loss: 1.8407 - val_acc: 0.6077
# Epoch 23/100
# 50000/50000 [==============================] - 164s 3ms/step - loss: 0.1838 - acc: 0.9396 - val_loss: 1.8979 - val_acc: 0.6053
# Epoch 24/100
# 50000/50000 [==============================] - 172s 3ms/step - loss: 0.1569 - acc: 0.9486 - val_loss: 2.0726 - val_acc: 0.6021
# Epoch 25/100
